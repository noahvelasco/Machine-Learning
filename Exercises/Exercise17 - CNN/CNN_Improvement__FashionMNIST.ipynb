# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
import tensorflow as tf
import numpy as np
import os
import distutils
#if distutils.version.LooseVersion(tf.__version__) <= '2.0':
#    raise Exception('This notebook is compatible with TensorFlow 1.14 or higher, for TensorFlow 1.13 or lower please use the previous version at https://github.com/tensorflow/tpu/blob/r1.13/tools/colab/fashion_mnist.ipynb')

#(x_train, y_train), (x_test, y_test) = tf.keras.datasets.mnist.load_data()
(x_train, y_train), (x_test, y_test) = tf.keras.datasets.fashion_mnist.load_data()
print(x_train.shape)
# add empty color dimension
x_train = np.expand_dims(x_train, -1)/255
x_test = np.expand_dims(x_test, -1)/255
# Convert y to one-hot
y_train = tf.keras.utils.to_categorical(y_train, 10)
y_test = tf.keras.utils.to_categorical(y_test, 10)
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/train-labels-idx1-ubyte.gz
# 32768/29515 [=================================] - 0s 0us/step
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/train-images-idx3-ubyte.gz
# 26427392/26421880 [==============================] - 0s 0us/step
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/t10k-labels-idx1-ubyte.gz
# 8192/5148 [===============================================] - 0s 0us/step
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/t10k-images-idx3-ubyte.gz
# 4423680/4422102 [==============================] - 0s 0us/step
# (60000, 28, 28)

# %%
import tensorflow as tf
from tensorflow.keras.layers import *
from keras.models import Model
from keras.optimizers import Adam, SGD
import numpy as np
import matplotlib.pyplot as plt
import os
import distutils

def create_model():
  model = tf.keras.models.Sequential()
  model.add(tf.keras.layers.Conv2D(32, (3, 3), input_shape=(28,28,1), activation='relu'))
  model.add(tf.keras.layers.MaxPooling2D(pool_size=(2, 2)))
  model.add(tf.keras.layers.Conv2D(64, (3, 3), activation='relu'))
  model.add(tf.keras.layers.MaxPooling2D(pool_size=(2, 2),padding='same'))
  model.add(tf.keras.layers.Flatten())
  model.add(tf.keras.layers.Dense(64,activation ='relu'))
  model.add(tf.keras.layers.Dense(10,activation = 'softmax'))
  return model

# %%
model = create_model()

#Prints Layers, shape and num of params
model.summary()

model.compile(loss="categorical_crossentropy", optimizer="adam", metrics=["accuracy"])

history = model.fit(x_train, y_train, batch_size=128, epochs=20, validation_data=(x_test, y_test))
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d (Conv2D)              (None, 26, 26, 32)        320
# _________________________________________________________________
# max_pooling2d (MaxPooling2D) (None, 13, 13, 32)        0
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 11, 11, 64)        18496
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 6, 6, 64)          0
# _________________________________________________________________
# flatten (Flatten)            (None, 2304)              0
# _________________________________________________________________
# dense (Dense)                (None, 64)                147520
# _________________________________________________________________
# dense_1 (Dense)              (None, 10)                650
# =================================================================
# Total params: 166,986
# Trainable params: 166,986
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/20
# 469/469 [==============================] - 2s 5ms/step - loss: 0.5250 - accuracy: 0.8119 - val_loss: 0.3926 - val_accuracy: 0.8598
# Epoch 2/20
# 469/469 [==============================] - 2s 5ms/step - loss: 0.3342 - accuracy: 0.8797 - val_loss: 0.3330 - val_accuracy: 0.8793
# Epoch 3/20
# 469/469 [==============================] - 2s 5ms/step - loss: 0.2845 - accuracy: 0.8971 - val_loss: 0.3033 - val_accuracy: 0.8878
# Epoch 4/20
# 469/469 [==============================] - 2s 5ms/step - loss: 0.2567 - accuracy: 0.9073 - val_loss: 0.2664 - val_accuracy: 0.9032
# Epoch 5/20
# 469/469 [==============================] - 2s 5ms/step - loss: 0.2342 - accuracy: 0.9151 - val_loss: 0.2698 - val_accuracy: 0.8992
# Epoch 6/20
# 469/469 [==============================] - 2s 5ms/step - loss: 0.2140 - accuracy: 0.9215 - val_loss: 0.2546 - val_accuracy: 0.9076
# Epoch 7/20
# 469/469 [==============================] - 2s 5ms/step - loss: 0.1952 - accuracy: 0.9276 - val_loss: 0.2596 - val_accuracy: 0.9083
# Epoch 8/20
# 469/469 [==============================] - 2s 5ms/step - loss: 0.1821 - accuracy: 0.9327 - val_loss: 0.2522 - val_accuracy: 0.9095
# Epoch 9/20
# 469/469 [==============================] - 2s 5ms/step - loss: 0.1694 - accuracy: 0.9379 - val_loss: 0.2416 - val_accuracy: 0.9115
# Epoch 10/20
# 469/469 [==============================] - 2s 5ms/step - loss: 0.1580 - accuracy: 0.9423 - val_loss: 0.2315 - val_accuracy: 0.9190
# Epoch 11/20
# 469/469 [==============================] - 2s 5ms/step - loss: 0.1449 - accuracy: 0.9467 - val_loss: 0.2373 - val_accuracy: 0.9206
# Epoch 12/20
# 469/469 [==============================] - 2s 5ms/step - loss: 0.1334 - accuracy: 0.9513 - val_loss: 0.2535 - val_accuracy: 0.9106
# Epoch 13/20
# 469/469 [==============================] - 2s 5ms/step - loss: 0.1212 - accuracy: 0.9557 - val_loss: 0.2312 - val_accuracy: 0.9252
# Epoch 14/20
# 469/469 [==============================] - 2s 5ms/step - loss: 0.1125 - accuracy: 0.9590 - val_loss: 0.2640 - val_accuracy: 0.9170
# Epoch 15/20
# 469/469 [==============================] - 2s 5ms/step - loss: 0.1002 - accuracy: 0.9633 - val_loss: 0.2561 - val_accuracy: 0.9199
# Epoch 16/20
# 469/469 [==============================] - 2s 5ms/step - loss: 0.0935 - accuracy: 0.9659 - val_loss: 0.2714 - val_accuracy: 0.9195
# Epoch 17/20
# 469/469 [==============================] - 2s 5ms/step - loss: 0.0864 - accuracy: 0.9677 - val_loss: 0.2746 - val_accuracy: 0.9170
# Epoch 18/20
# 469/469 [==============================] - 2s 5ms/step - loss: 0.0754 - accuracy: 0.9728 - val_loss: 0.2792 - val_accuracy: 0.9192
# Epoch 19/20
# 469/469 [==============================] - 2s 5ms/step - loss: 0.0682 - accuracy: 0.9751 - val_loss: 0.2871 - val_accuracy: 0.9189
# Epoch 20/20
# 469/469 [==============================] - 2s 5ms/step - loss: 0.0627 - accuracy: 0.9773 - val_loss: 0.3113 - val_accuracy: 0.9160

# %%
fig, ax = plt.subplots()
ax.plot(history.history['accuracy'],label = 'train')
ax.plot(history.history['val_accuracy'],label = 'test')
ax.set_title('Accuracy')
ax.legend(loc='lower right')
fig, ax = plt.subplots()
ax.plot(history.history['loss'],label = 'train')
ax.plot(history.history['val_loss'],label = 'test')
ax.set_title('Loss')
ax.legend(loc='upper right')
